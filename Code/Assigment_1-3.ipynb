# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon, MultiPolygon
from geoalchemy2 import Geometry, WKTElement
import matplotlib.pyplot as plt
import numpy as np
from sqlalchemy import inspect
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-066e84e0948e> in <module>
#       1 import pandas as pd
# ----> 2 import geopandas as gpd
#       3 from shapely.geometry import Point, Polygon, MultiPolygon
#       4 from geoalchemy2 import Geometry, WKTElement
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
from sqlalchemy import create_engine
import psycopg2
import psycopg2.extras
import json
import os

credentials = "Credentials.json"

def pgconnect(credential_filepath, db_schema="public"):
    with open(credential_filepath) as f:
        db_conn_dict = json.load(f)
        host       = db_conn_dict['host']
        db_user    = db_conn_dict['user']
        db_pw      = db_conn_dict['password']
        default_db = db_conn_dict['user']
        try:
            db = create_engine('postgresql+psycopg2://'+db_user+':'+db_pw+'@'+host+'/'+default_db, echo=False)
            conn = db.connect()
            print('Connected successfully.')
        except Exception as e:
            print("Unable to connect to the database.")
            print(e)
            db, conn = None, None
        return db,conn

def query(conn, sqlcmd, args=None, df=True):
    result = pd.DataFrame() if df else None
    try:
        if df:
            result = pd.read_sql_query(sqlcmd, conn, params=args)
        else:
            result = conn.execute(sqlcmd, args).fetchall()
            result = result[0] if len(result) == 1 else result
    except Exception as e:
        print("Error encountered: ", e, sep='\n')
    return result
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-45dfd8af6629> in <module>
#       1 from sqlalchemy import create_engine
# ----> 2 import psycopg2
#       3 import psycopg2.extras
#       4 import json
#       5 import os
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
db, conn = pgconnect(credentials)
# Out:
# Connected successfully.

# %%
query(conn, "select PostGIS_Version()")
# Out:
#                          postgis_version
# 0  3.0 USE_GEOS=1 USE_PROJ=1 USE_STATS=1

# %% [markdown]
# # TASK 01

# %% [markdown]
# ## Neighbourhoods.csv

# %%
neighbourhoods = pd.read_csv("Neighbourhoods.csv")
#cleaning
del neighbourhoods['Unnamed: 0']
neighbourhoods.fillna(method = 'ffill', inplace = True)
neighbourhoods["population"] = neighbourhoods["population"].replace(",","", regex = True)
neighbourhoods["number_of_dwellings"] = neighbourhoods["number_of_dwellings"].replace(",","", regex = True)
neighbourhoods["population"] = neighbourhoods["population"].astype(str).astype(np.int64)
neighbourhoods["number_of_dwellings"] = neighbourhoods["number_of_dwellings"].astype(str).astype(np.int64)
neighbourhoods

#business_stats = pd.read_csv('BusinessStats.csv')
#school_catchments = gpd.read_file("school_catchments/catchments_future.shp")
# Out:
#        area_id                    area_name   land_area  population  \
# 0    102011028     Avoca Beach - Copacabana    643.8000        7590
# 1    102011029  Box Head - MacMasters Beach   3208.6000       10986
# 2    102011030              Calga - Kulnura  76795.1000        4841
# 3    102011031          Erina - Green Point   3379.3000       14237
# 4    102011032        Gosford - Springfield   1691.2000       19385
# ..         ...                          ...         ...         ...
# 317  106011109              Cessnock Region   1570.4341        7931
# 318  106011113             Singleton Region   4067.2349        4919
# 319  111021218        Morisset - Cooranbong    330.5208       14959
# 320  114021285         Hill Top - Colo Vale    174.3752        6025
# 321  114021289           Southern Highlands   1409.7013        6589
#
#      number_of_dwellings  number_of_businesses  \
# 0                   2325                 738.0
# 1                   3847                 907.0
# 2                   1575                1102.0
# 3                   4450                1666.0
# 4                   6373                2126.0
# ..                   ...                   ...
# 317                 3281                 673.0
# 318                 2055                 698.0
# 319                 6298                1154.0
# 320                 2249                 400.0
# 321                 3405                 856.0
#
#      median_annual_household_income  avg_monthly_rent   0-4   5-9  10-14  \
# 0                           46996.0            1906.0   467   583    604
# 1                           42621.0            1682.0   586   696    661
# 2                           42105.0            1182.0   220   254    304
# 3                           43481.0            1595.0   695   778    916
# 4                           45972.0            1382.0  1200  1079    963
# ..                              ...               ...   ...   ...    ...
# 317                         73164.0            1080.0   432   590    577
# 318                         87984.0            1000.0   310   394    353
# 319                         58084.0            1260.0   813   855    828
# 320                         81120.0            1512.0   443   500    470
# 321                         65572.0            1200.0   295   388    401
#
#      15-19
# 0      560
# 1      692
# 2      320
# 3      838
# 4      977
# ..     ...
# 317    527
# 318    323
# 319    962
# 320    451
# 321    350
#
# [322 rows x 12 columns]

# %% [markdown]
# ### Initializing table for Neighbourhoods.csv

# %%
# neighberhoods.to_sql("neighberhoods", con=conn, if_exists='append', index=False)
# query(conn, "select * from neighberhoods")


conn.execute("""
DROP TABLE IF EXISTS neighbourhoods cascade;;
CREATE TABLE neighbourhoods(
   area_id INTEGER PRIMARY KEY,
   area_name VARCHAR(50),
   land_area FLOAT,
   population INTEGER,
   number_of_dwellings INTEGER,
   number_of_businesses INTEGER,
   median_annual_household_income FLOAT,
   avg_monthly_rent FLOAT,
   "0-4" INTEGER,
   "5-9" INTEGER,
   "10-14" INTEGER,
   "15-19" INTEGER  
);""")

neighbourhoods.to_sql("neighbourhoods", con = conn, if_exists='append', index = False)
neighbourhood = query(conn, "select * from neighbourhoods limit 10")
neighbourhood
# Out:
#      area_id                    area_name  land_area  population  \
# 0  102011028     Avoca Beach - Copacabana      643.8        7590
# 1  102011029  Box Head - MacMasters Beach     3208.6       10986
# 2  102011030              Calga - Kulnura    76795.1        4841
# 3  102011031          Erina - Green Point     3379.3       14237
# 4  102011032        Gosford - Springfield     1691.2       19385
# 5  102011033                      Kariong      830.6        6540
# 6  102011034  Kincumber - Picketts Valley     1208.9        7428
# 7  102011035                       Narara      770.2        6853
# 8  102011036       Niagara Park - Lisarow     1673.2        8173
# 9  102011037      Point Clare - Koolewong      678.7        6281
#
#    number_of_dwellings  number_of_businesses  median_annual_household_income  \
# 0                 2325                   738                         46996.0
# 1                 3847                   907                         42621.0
# 2                 1575                  1102                         42105.0
# 3                 4450                  1666                         43481.0
# 4                 6373                  2126                         45972.0
# 5                 1824                   352                         47896.0
# 6                 1946                   479                         41642.0
# 7                 2006                   292                         46660.0
# 8                 2345                   477                         45762.0
# 9                 2220                   312                         45966.0
#
#    avg_monthly_rent   0-4   5-9  10-14  15-19
# 0            1906.0   467   583    604    560
# 1            1682.0   586   696    661    692
# 2            1182.0   220   254    304    320
# 3            1595.0   695   778    916    838
# 4            1382.0  1200  1079    963    977
# 5            1649.0   472   502    497    591
# 6            1397.0   404   458    448    416
# 7            1512.0   463   470    448    459
# 8            1495.0   525   605    617    606
# 9            1572.0   371   412    373    343

# %% [markdown]
# ## BusinessStats.csv

# %%
business_stats = pd.read_csv('BusinessStats.csv')
business_stats.fillna(method = 'ffill', inplace = True)
print(business_stats.dtypes)
# Out:
# area_id                               int64
# area_name                            object
# number_of_businesses                  int64
# accommodation_and_food_services       int64
# retail_trade                          int64
# agriculture_forestry_and_fishing      int64
# health_care_and_social_assistance     int64
# public_administration_and_safety      int64
# transport_postal_and_warehousing      int64
# dtype: object

# %% [markdown]
# ### Initializing table for BusinessStats.csv

# %%
conn.execute("""
DROP TABLE IF EXISTS business_stats;
CREATE TABLE business_stats(
   area_id INTEGER PRIMARY KEY,
   area_name VARCHAR(50),
   number_of_businesses INTEGER,
   accommodation_and_food_services INTEGER,
   retail_trade INTEGER,
   agriculture_forestry_and_fishing INTEGER,
   health_care_and_social_assistance INTEGER,
   public_administration_and_safety INTEGER,
   transport_postal_and_warehousing INTEGER
);""")
business_stats.to_sql("business_stats", con = conn, if_exists='append', index = False)
query(conn, "select * from business_stats limit 10")
# Out:
#      area_id                        area_name  number_of_businesses  \
# 0  101021007                        Braidwood                   629
# 1  101021008                          Karabar                   326
# 2  101021009                       Queanbeyan                   724
# 3  101021010                Queanbeyan - East                   580
# 4  101021011                Queanbeyan Region                  1642
# 5  101021012  Queanbeyan West - Jerrabomberra                   885
# 6  101031013                          Bombala                   419
# 7  101031014                            Cooma                   714
# 8  101031015                     Cooma Region                   478
# 9  101031016            Jindabyne - Berridale                  1032
#
#    accommodation_and_food_services  retail_trade  \
# 0                               26            27
# 1                                7            10
# 2                               52            47
# 3                               16            23
# 4                               39            63
# 5                               14            48
# 6                               18            14
# 7                               55            47
# 8                               11            15
# 9                              144            59
#
#    agriculture_forestry_and_fishing  health_care_and_social_assistance  \
# 0                               280                                 11
# 1                                 8                                 11
# 2                                11                                 56
# 3                                 4                                 12
# 4                               292                                 34
# 5                                14                                 29
# 6                               250                                  9
# 7                               110                                 36
# 8                               258                                  5
# 9                               161                                 43
#
#    public_administration_and_safety  transport_postal_and_warehousing
# 0                                 0                                35
# 1                                 0                                43
# 2                                 3                                77
# 3                                 0                                57
# 4                                 7                                81
# 5                                 3                                59
# 6                                 0                                14
# 7                                 0                                49
# 8                                 0                                26
# 9                                 3                                27

# %% [markdown]
# # Combining Neighbourhoods and BusinessStats

# %%
sql = """SELECT *
  FROM neighbourhoods N
      LEFT OUTER JOIN business_stats B ON (B.area_id = N.area_id);"""
cobined_neighbourhood_businessstat = query(conn, sql)
cobined_neighbourhood_businessstat
# Out:
#        area_id                    area_name   land_area  population  \
# 0    101051540              Goulburn Region   9035.1221       12670
# 1    102011028     Avoca Beach - Copacabana    643.8000        7590
# 2    102011029  Box Head - MacMasters Beach   3208.6000       10986
# 3    102011030              Calga - Kulnura  76795.1000        4841
# 4    102011031          Erina - Green Point   3379.3000       14237
# ..         ...                          ...         ...         ...
# 317  128021537          Royal National Park  13933.4000          28
# 318  128021538        Sutherland - Kirrawee    775.5000       21760
# 319  128021607                     Engadine    895.4000       17424
# 320  128021608         Loftus - Yarrawarrah    384.4000        7426
# 321  128021609             Woronora Heights    313.7000        3681
#
#      number_of_dwellings number_of_businesses  median_annual_household_income  \
# 0                   6817                 1528                         62712.0
# 1                   2325                  738                         46996.0
# 2                   3847                  907                         42621.0
# 3                   1575                 1102                         42105.0
# 4                   4450                 1666                         43481.0
# ..                   ...                  ...                             ...
# 317                    4                    3                         55391.0
# 318                 6924                 2086                         53378.0
# 319                 5219                 1121                         52667.0
# 320                 2177                  417                         51243.0
# 321                 1050                  259                         54935.0
#
#      avg_monthly_rent   0-4   5-9  ...  15-19    area_id  \
# 0               800.0   685   766  ...    752  101051540
# 1              1906.0   467   583  ...    560  102011028
# 2              1682.0   586   696  ...    692  102011029
# 3              1182.0   220   254  ...    320  102011030
# 4              1595.0   695   778  ...    838  102011031
# ..                ...   ...   ...  ...    ...        ...
# 317            1899.0     0     4  ...      4  128021537
# 318            1809.0  1538  1242  ...   1033  128021538
# 319            1955.0  1333  1529  ...   1031  128021607
# 320            2163.0   503   572  ...    447  128021608
# 321            2300.0   175   228  ...    343  128021609
#
#                        area_name number_of_businesses  \
# 0                Goulburn Region                 1891
# 1       Avoca Beach - Copacabana                  724
# 2    Box Head - MacMasters Beach                  934
# 3                Calga - Kulnura                 1134
# 4            Erina - Green Point                 1712
# ..                           ...                  ...
# 317          Royal National Park                    3
# 318        Sutherland - Kirrawee                 2136
# 319                     Engadine                 1106
# 320         Loftus - Yarrawarrah                  452
# 321             Woronora Heights                  265
#
#      accommodation_and_food_services  retail_trade  \
# 0                                 38            52
# 1                                 33            35
# 2                                 23            45
# 3                                 14            43
# 4                                 68           145
# ..                               ...           ...
# 317                                3             0
# 318                               73           113
# 319                               37            69
# 320                                9            20
# 321                                4            12
#
#      agriculture_forestry_and_fishing  health_care_and_social_assistance  \
# 0                                1041                                 33
# 1                                   4                                 60
# 2                                  13                                 43
# 3                                 231                                 12
# 4                                  19                                179
# ..                                ...                                ...
# 317                                 0                                  0
# 318                                 6                                127
# 319                                 3                                 82
# 320                                 3                                 25
# 321                                 0                                 11
#
#      public_administration_and_safety  transport_postal_and_warehousing
# 0                                   3                                81
# 1                                   0                                19
# 2                                   3                                28
# 3                                   0                                55
# 4                                  12                                43
# ..                                ...                               ...
# 317                                 0                                 0
# 318                                17                               122
# 319                                 9                                51
# 320                                 5                                31
# 321                                 0                                14
#
# [322 rows x 21 columns]

# %% [markdown]
# # Reading in Catchment and Break-in Data

# %%
catchments_primary = gpd.read_file("catchments_primary.shp")
catchments_primary
# Out:
#      USE_ID CATCH_TYPE         USE_DESC  ADD_DATE KINDERGART YEAR1 YEAR2  \
# 0      2838    PRIMARY       Parklea PS  20181210          Y     Y     Y
# 1      3943    PRIMARY       Gordon WPS  20211219          Y     Y     Y
# 2      2404    PRIMARY    Lindfield EPS  20211219          Y     Y     Y
# 3      4393    PRIMARY  Carlingford WPS  20220223          Y     Y     Y
# 4      4615    PRIMARY   Caddies Ck  PS  20181210          Y     Y     Y
# ...     ...        ...              ...       ...        ...   ...   ...
# 1661   4383    PRIMARY   E A Southee PS  20200315          Y     Y     Y
# 1662   3275    PRIMARY    Tumbarumba PS  20200507          Y     Y     Y
# 1663   2239    PRIMARY       Jindera PS  20200507          Y     Y     Y
# 1664   3594    PRIMARY         Louth PS  20200604          Y     Y     Y
# 1665   2155    PRIMARY     Hermidale PS  20200604          Y     Y     Y
#
#      YEAR3 YEAR4 YEAR5 YEAR6 YEAR7 YEAR8 YEAR9 YEAR10 YEAR11 YEAR12 PRIORITY  \
# 0        Y     Y     Y     Y     N     N     N      N      N      N     None
# 1        Y     Y     Y     Y     N     N     N      N      N      N     None
# 2        Y     Y     Y     Y     N     N     N      N      N      N     None
# 3        Y     Y     Y     Y     N     N     N      N      N      N     None
# 4        Y     Y     Y     Y     N     N     N      N      N      N     None
# ...    ...   ...   ...   ...   ...   ...   ...    ...    ...    ...      ...
# 1661     Y     Y     Y     Y     N     N     N      N      N      N     None
# 1662     Y     Y     Y     Y     N     N     N      N      N      N     None
# 1663     Y     Y     Y     Y     N     N     N      N      N      N     None
# 1664     Y     Y     Y     Y     N     N     N      N      N      N     None
# 1665     Y     Y     Y     Y     N     N     N      N      N      N     None
#
#                                                geometry
# 0     POLYGON ((150.93564 -33.71612, 150.93715 -33.7...
# 1     POLYGON ((151.14085 -33.74463, 151.14113 -33.7...
# 2     POLYGON ((151.18336 -33.74748, 151.18443 -33.7...
# 3     POLYGON ((151.04518 -33.77303, 151.04526 -33.7...
# 4     POLYGON ((150.92567 -33.72960, 150.92602 -33.7...
# ...                                                 ...
# 1661  POLYGON ((147.94621 -34.55863, 147.95292 -34.5...
# 1662  POLYGON ((148.12885 -35.60082, 148.23155 -35.6...
# 1663  POLYGON ((146.86148 -35.87511, 146.87402 -35.8...
# 1664  POLYGON ((145.18403 -29.65805, 145.18434 -29.6...
# 1665  POLYGON ((146.46001 -31.31688, 146.47453 -31.3...
#
# [1666 rows x 19 columns]

# %%
catchments_secondary = gpd.read_file("catchments_secondary.shp")
catchments_secondary
# Out:
#     USE_ID    CATCH_TYPE             USE_DESC  ADD_DATE KINDERGART YEAR1  \
# 0     8503     HIGH_COED         Billabong HS  20200507          N     N
# 1     8266     HIGH_COED      James Fallon HS  20200507          N     N
# 2     8505     HIGH_COED            Murray HS  20200507          N     N
# 3     8246     HIGH_COED         Heathcote HS      None          N     N
# 4     8458     HIGH_COED         Kingswood HS  20201016          N     N
# ..     ...           ...                  ...       ...        ...   ...
# 430   8213     HIGH_BOYS          Birrong BHS  20211221          N     N
# 431   8857    HIGH_GIRLS  GRC Penshurst Girls  20220110          N     N
# 432   3235  CENTRAL_HIGH         Tooleybuc CS  20200512          N     N
# 433   1115  CENTRAL_HIGH         Balranald CS  20200512          N     N
# 434   2213  CENTRAL_HIGH           Ivanhoe CS  20200512          N     N
#
#     YEAR2 YEAR3 YEAR4 YEAR5 YEAR6 YEAR7 YEAR8 YEAR9 YEAR10 YEAR11 YEAR12  \
# 0       N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 1       N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 2       N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 3       N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 4       N     N     N     N     N     Y     Y     Y      Y      Y      Y
# ..    ...   ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 430     N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 431     N     N     N     N     N     Y     Y     Y      Y      N      N
# 432     N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 433     N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 434     N     N     N     N     N     Y     Y     Y      Y      Y      Y
#
#     PRIORITY                                           geometry
# 0       None  POLYGON ((146.67182 -35.31444, 146.68930 -35.3...
# 1       None  POLYGON ((147.08734 -35.86271, 147.10413 -35.8...
# 2       None  POLYGON ((146.81448 -35.78341, 146.81250 -35.7...
# 3       None  POLYGON ((151.03281 -34.02521, 151.03267 -34.0...
# 4       None  MULTIPOLYGON (((150.68600 -33.74031, 150.68631...
# ..       ...                                                ...
# 430     None  POLYGON ((151.05364 -33.85076, 151.06142 -33.8...
# 431     None  POLYGON ((151.07573 -33.95089, 151.07921 -33.9...
# 432     None  POLYGON ((143.37723 -34.80173, 143.39037 -34.8...
# 433     None  POLYGON ((143.65541 -33.55702, 143.65541 -33.5...
# 434     None  POLYGON ((144.31579 -32.17239, 144.32923 -32.1...
#
# [435 rows x 19 columns]

# %%
catchments_future = gpd.read_file("catchments_future.shp")
catchments_future
# Out:
#    USE_ID    CATCH_TYPE                USE_DESC  ADD_DATE  KINDERGART  YEAR1  \
# 0    2133       PRIMARY              Harbord PS  20200720        2023   2023
# 1    4450       PRIMARY              Berinba PS  20220110        2023   2023
# 2    4683       PRIMARY        Murrumbateman PS  20220110        2023   2023
# 3    4021       PRIMARY           Manly Vale PS  20200805        2023   2023
# 4    8161     HIGH_BOYS            Randwick BHS  20200220           0      0
# 5    2469       PRIMARY               Manly WPS  20200805        2023   2023
# 6    8463     HIGH_COED             Sylvania HS  20210217           0      0
# 7    8404     HIGH_COED         Endeavour Sp HS  20210217           0      0
# 8    3827       PRIMARY           Narraweena PS  20200720        2023   2023
# 9    8555     HIGH_COED             Rose Bay SC  20200220           0      0
# 10   8507     HIGH_COED          SSC Leichhardt  20200220           0      0
# 11   8484     HIGH_COED             SSC Balmain  20200220           0      0
# 12   8556  CENTRAL_HIGH      Alexandria Park CS  20200220           0      0
# 13   8539     HIGH_COED     SSC Blackwattle Bay  20200220           0      0
# 14   8913     HIGH_COED         Inner Sydney HS  20200220           0      0
# 15   8852     HIGH_COED          The Jannali HS  20210303           0      0
# 16   8432     HIGH_COED             Engadine HS  20210303           0      0
# 17   8286     HIGH_COED             Mt Annan HS  20220301           0      0
# 18   8584     HIGH_COED  Elizabeth Macarthur HS  20220301           0      0
# 19   3971       PRIMARY          Beacon Hill PS  20200720        2023   2023
# 20   4241       PRIMARY               Cromer PS  20200720        2023   2023
# 21   8290     HIGH_COED       John Edmondson HS  20190520           0      0
# 22   1744       PRIMARY              Dee Why PS  20200720        2023   2023
# 23   8916     HIGH_COED            Oran Park HS  20190520           0      0
# 24   8575     HIGH_COED       Robert Townson HS  20190520           0      0
# 25   3925       PRIMARY           Curl Curl NPS  20200720        2023   2023
# 26   8569     HIGH_COED           Eagle Vale HS  20190520           0      0
# 27   8220    HIGH_GIRLS            Randwick GHS  20200220           0      0
# 28   1379       PRIMARY            Brookvale PS  20200720        2023   2023
# 29   4200       PRIMARY         Allambie Hts PS  20200720        2023   2023
# 30   4678       PRIMARY         Epping South PS  20220305        2023   2023
# 31   7416       PRIMARY             Eastwood PS  20220305        2023   2023
# 32   7302       PRIMARY          Carlingford PS  20220305        2023   2023
# 33   4127       PRIMARY          Queanbeyan WPS  20220305        2023   2023
# 34   2922       PRIMARY           Queanbeyan PS  20220305        2023   2023
# 35   4394       PRIMARY          Queanbeyan SPS  20220305        2023   2023
# 36   4633       PRIMARY        Jerrabomberra PS  20220305        2023   2023
# 37   1851       PRIMARY              Epping WPS  20220305        2023   2023
# 38   8524     HIGH_COED              Karabar HS  20220305           0      0
# 39   4680       PRIMARY              Googong PS  20220305        2023   2023
# 40   2540       PRIMARY            Michelago PS  20220305        2023   2023
# 41   8922     HIGH_COED        Jerrabomberra HS  20220305           0      0
# 42   8919     HIGH_COED           Bungendore HS  20220305           0      0
# 43   8216     HIGH_COED           Queanbeyan HS  20220305           0      0
#
#     YEAR2  YEAR3  YEAR4  YEAR5  YEAR6  YEAR7  YEAR8  YEAR9  YEAR10  YEAR11  \
# 0    2023   2023   2023   2023   2023      0      0      0       0       0
# 1    2023   2023   2023   2023   2023      0      0      0       0       0
# 2    2023   2023   2023   2023   2023      0      0      0       0       0
# 3    2023   2023   2023   2023   2023      0      0      0       0       0
# 4       0      0      0      0      0   2023   2023   2023    2023    2023
# 5    2023   2023   2023   2023   2023      0      0      0       0       0
# 6       0      0      0      0      0   2023   2023   2023    2023    2023
# 7       0      0      0      0      0   2023   2023   2023    2023    2023
# 8    2023   2023   2023   2023   2023      0      0      0       0       0
# 9       0      0      0      0      0   2023   2023   2023    2023    2023
# 10      0      0      0      0      0   2023   2023   2023    2023       0
# 11      0      0      0      0      0   2023   2023   2023    2023       0
# 12      0      0      0      0      0   2023   2023   2023    2023    2023
# 13      0      0      0      0      0      0      0      0       0    2023
# 14      0      0      0      0      0   2023   2023   2023    2023    2024
# 15      0      0      0      0      0   2023   2023   2023    2023    2023
# 16      0      0      0      0      0   2023   2023   2023    2023    2023
# 17      0      0      0      0      0   2023   2023   2023    2023    2023
# 18      0      0      0      0      0   2023   2023   2023    2023    2023
# 19   2023   2023   2023   2023   2023      0      0      0       0       0
# 20   2023   2023   2023   2023   2023      0      0      0       0       0
# 21      0      0      0      0      0   2023   2023   2023    2023    2023
# 22   2023   2023   2023   2023   2023      0      0      0       0       0
# 23      0      0      0      0      0   2023   2023   2023    2023    2023
# 24      0      0      0      0      0   2023   2023   2023    2023    2023
# 25   2023   2023   2023   2023   2023      0      0      0       0       0
# 26      0      0      0      0      0   2023   2023   2023    2023    2023
# 27      0      0      0      0      0   2023   2023   2023    2023    2023
# 28   2023   2023   2023   2023   2023      0      0      0       0       0
# 29   2023   2023   2023   2023   2023      0      0      0       0       0
# 30   2023   2023   2023   2023   2023      0      0      0       0       0
# 31   2023   2023   2023   2023   2023      0      0      0       0       0
# 32   2023   2023   2023   2023   2023      0      0      0       0       0
# 33   2023   2023   2023   2023   2023      0      0      0       0       0
# 34   2023   2023   2023   2023   2023      0      0      0       0       0
# 35   2023   2023   2023   2023   2023      0      0      0       0       0
# 36   2023   2023   2023   2023   2023      0      0      0       0       0
# 37   2023   2023   2023   2023   2023      0      0      0       0       0
# 38      0      0      0      0      0   2023   2023   2023    2023    2023
# 39   2023   2023   2023   2023   2023      0      0      0       0       0
# 40   2023   2023   2023   2023   2023      0      0      0       0       0
# 41      0      0      0      0      0   2023   2023      0       0       0
# 42      0      0      0      0      0   2023   2023      0       0       0
# 43      0      0      0      0      0   2023   2023   2023    2023    2023
#
#     YEAR12                                           geometry
# 0        0  POLYGON ((151.29769 -33.76832, 151.29731 -33.7...
# 1        0  POLYGON ((149.10301 -34.82127, 149.10167 -34.8...
# 2        0  POLYGON ((149.10557 -34.89523, 149.11035 -34.8...
# 3        0  POLYGON ((151.27162 -33.76913, 151.27116 -33.7...
# 4     2023  POLYGON ((151.27152 -33.91402, 151.27152 -33.9...
# 5        0  POLYGON ((151.28453 -33.78790, 151.28559 -33.7...
# 6     2023  POLYGON ((151.14827 -33.99111, 151.14859 -33.9...
# 7     2023  POLYGON ((151.12719 -34.01025, 151.12706 -34.0...
# 8        0  POLYGON ((151.26725 -33.74242, 151.26789 -33.7...
# 9     2023  POLYGON ((151.28072 -33.83287, 151.28095 -33.8...
# 10       0  POLYGON ((151.15647 -33.86923, 151.15684 -33.8...
# 11       0  POLYGON ((151.15327 -33.84363, 151.15317 -33.8...
# 12    2023  POLYGON ((151.19497 -33.88876, 151.19524 -33.8...
# 13    2023  POLYGON ((151.15327 -33.84363, 151.15317 -33.8...
# 14    2025  POLYGON ((151.20982 -33.85423, 151.21071 -33.8...
# 15    2023  POLYGON ((151.06985 -33.99599, 151.06995 -33.9...
# 16    2023  POLYGON ((151.04674 -34.03603, 151.04761 -34.0...
# 17    2023  POLYGON ((150.77298 -34.02516, 150.77487 -34.0...
# 18    2023  POLYGON ((150.73235 -34.01466, 150.73326 -34.0...
# 19       0  POLYGON ((151.24976 -33.72339, 151.25563 -33.7...
# 20       0  POLYGON ((151.27281 -33.72239, 151.27309 -33.7...
# 21    2023  MULTIPOLYGON (((150.70497 -33.90426, 150.71625...
# 22       0  POLYGON ((151.29341 -33.73980, 151.29451 -33.7...
# 23    2024  POLYGON ((150.75452 -33.95472, 150.75653 -33.9...
# 24    2023  POLYGON ((150.82116 -33.97644, 150.82231 -33.9...
# 25       0  POLYGON ((151.29952 -33.75522, 151.29955 -33.7...
# 26    2023  POLYGON ((150.80290 -34.01178, 150.80389 -34.0...
# 27    2023  POLYGON ((151.27152 -33.91402, 151.27152 -33.9...
# 28       0  POLYGON ((151.28295 -33.75267, 151.28288 -33.7...
# 29       0  POLYGON ((151.24862 -33.75664, 151.25105 -33.7...
# 30       0  POLYGON ((151.07651 -33.77686, 151.07662 -33.7...
# 31       0  POLYGON ((151.07905 -33.78355, 151.07959 -33.7...
# 32       0  POLYGON ((151.05139 -33.77598, 151.05187 -33.7...
# 33       0  POLYGON ((149.22287 -35.35695, 149.22023 -35.3...
# 34       0  POLYGON ((149.23247 -35.34289, 149.23562 -35.3...
# 35       0  POLYGON ((149.23418 -35.36473, 149.23333 -35.3...
# 36       0  POLYGON ((149.19808 -35.38147, 149.19852 -35.3...
# 37       0  POLYGON ((151.06910 -33.76741, 151.06983 -33.7...
# 38    2023  POLYGON ((149.23538 -35.36390, 149.23582 -35.3...
# 39       0  POLYGON ((149.26653 -35.49838, 149.26703 -35.5...
# 40       0  POLYGON ((149.14237 -35.56872, 149.16075 -35.5...
# 41       0  POLYGON ((149.19808 -35.38147, 149.19852 -35.3...
# 42       0  POLYGON ((149.24085 -34.91439, 149.24367 -34.9...
# 43    2023  POLYGON ((149.25674 -35.33186, 149.25847 -35.3...

# %%
catchments = pd.concat([catchments_primary, catchments_secondary, catchments_future], ignore_index = True)
catchments
# Out:
#      USE_ID CATCH_TYPE          USE_DESC  ADD_DATE KINDERGART YEAR1 YEAR2  \
# 0      2838    PRIMARY        Parklea PS  20181210          Y     Y     Y
# 1      3943    PRIMARY        Gordon WPS  20211219          Y     Y     Y
# 2      2404    PRIMARY     Lindfield EPS  20211219          Y     Y     Y
# 3      4393    PRIMARY   Carlingford WPS  20220223          Y     Y     Y
# 4      4615    PRIMARY    Caddies Ck  PS  20181210          Y     Y     Y
# ...     ...        ...               ...       ...        ...   ...   ...
# 2140   4680    PRIMARY        Googong PS  20220305       2023  2023  2023
# 2141   2540    PRIMARY      Michelago PS  20220305       2023  2023  2023
# 2142   8922  HIGH_COED  Jerrabomberra HS  20220305          0     0     0
# 2143   8919  HIGH_COED     Bungendore HS  20220305          0     0     0
# 2144   8216  HIGH_COED     Queanbeyan HS  20220305          0     0     0
#
#      YEAR3 YEAR4 YEAR5 YEAR6 YEAR7 YEAR8 YEAR9 YEAR10 YEAR11 YEAR12 PRIORITY  \
# 0        Y     Y     Y     Y     N     N     N      N      N      N     None
# 1        Y     Y     Y     Y     N     N     N      N      N      N     None
# 2        Y     Y     Y     Y     N     N     N      N      N      N     None
# 3        Y     Y     Y     Y     N     N     N      N      N      N     None
# 4        Y     Y     Y     Y     N     N     N      N      N      N     None
# ...    ...   ...   ...   ...   ...   ...   ...    ...    ...    ...      ...
# 2140  2023  2023  2023  2023     0     0     0      0      0      0      NaN
# 2141  2023  2023  2023  2023     0     0     0      0      0      0      NaN
# 2142     0     0     0     0  2023  2023     0      0      0      0      NaN
# 2143     0     0     0     0  2023  2023     0      0      0      0      NaN
# 2144     0     0     0     0  2023  2023  2023   2023   2023   2023      NaN
#
#                                                geometry
# 0     POLYGON ((150.93564 -33.71612, 150.93715 -33.7...
# 1     POLYGON ((151.14085 -33.74463, 151.14113 -33.7...
# 2     POLYGON ((151.18336 -33.74748, 151.18443 -33.7...
# 3     POLYGON ((151.04518 -33.77303, 151.04526 -33.7...
# 4     POLYGON ((150.92567 -33.72960, 150.92602 -33.7...
# ...                                                 ...
# 2140  POLYGON ((149.26653 -35.49838, 149.26703 -35.5...
# 2141  POLYGON ((149.14237 -35.56872, 149.16075 -35.5...
# 2142  POLYGON ((149.19808 -35.38147, 149.19852 -35.3...
# 2143  POLYGON ((149.24085 -34.91439, 149.24367 -34.9...
# 2144  POLYGON ((149.25674 -35.33186, 149.25847 -35.3...
#
# [2145 rows x 19 columns]

# %%
break_ins = gpd.read_file("BreakEnterDwelling_JanToDec2021.shp")
break_ins
# Out:
#       OBJECTID  Contour       Density  ORIG_FID  Shape_Leng  Shape_Area  \
# 0            1      8.0   Low Density         1    0.012138    0.000006
# 1            2      8.0   Low Density         1    0.019106    0.000015
# 2            3      8.0   Low Density         1    0.006068    0.000002
# 3            4      8.0   Low Density         1    0.011006    0.000006
# 4            5      8.0   Low Density         1    0.008073    0.000003
# ...        ...      ...           ...       ...         ...         ...
# 2589      2590     10.0  High Density         3    0.015358    0.000011
# 2590      2591     10.0  High Density         3    0.028327    0.000029
# 2591      2592     10.0  High Density         3    0.006654    0.000002
# 2592      2593     10.0  High Density         3    0.047098    0.000044
# 2593      2594     10.0  High Density         3    0.016336    0.000014
#
#                                                geometry
# 0     POLYGON ((149.91078 -37.06636, 149.91080 -37.0...
# 1     POLYGON ((149.90601 -37.05837, 149.90602 -37.0...
# 2     POLYGON ((148.94250 -37.04209, 148.94253 -37.0...
# 3     POLYGON ((149.19583 -36.91833, 149.19584 -36.9...
# 4     POLYGON ((149.84836 -36.68459, 149.84838 -36.6...
# ...                                                 ...
# 2589  POLYGON ((153.27961 -28.55388, 153.27964 -28.5...
# 2590  POLYGON ((150.35939 -28.60530, 150.35941 -28.6...
# 2591  POLYGON ((153.56825 -28.38307, 153.56828 -28.3...
# 2592  POLYGON ((153.53917 -28.18858, 153.53920 -28.1...
# 2593  POLYGON ((153.54243 -28.16992, 153.54246 -28.1...
#
# [2594 rows x 7 columns]

# %% [markdown]
# ## Reading in SA2 Shape Data

# %%
sa_two = gpd.read_file("SA2_2016_AUST.shp")
sa_two.drop(sa_two[(sa_two['geometry'] == None)].index, inplace = True)
sa_two
# Out:
#      SA2_MAIN16 SA2_5DIG16               SA2_NAME16 SA3_CODE16  \
# 0     101021007      11007                Braidwood      10102
# 1     101021008      11008                  Karabar      10102
# 2     101021009      11009               Queanbeyan      10102
# 3     101021010      11010        Queanbeyan - East      10102
# 4     101021011      11011        Queanbeyan Region      10102
# ...         ...        ...                      ...        ...
# 2301  801111141      81141                  Namadgi      80111
# 2304  901011001      91001         Christmas Island      90101
# 2305  901021002      91002  Cocos (Keeling) Islands      90102
# 2306  901031003      91003               Jervis Bay      90103
# 2307  901041004      91004           Norfolk Island      90104
#
#                    SA3_NAME16 SA4_CODE16                    SA4_NAME16  \
# 0                  Queanbeyan        101                Capital Region
# 1                  Queanbeyan        101                Capital Region
# 2                  Queanbeyan        101                Capital Region
# 3                  Queanbeyan        101                Capital Region
# 4                  Queanbeyan        101                Capital Region
# ...                       ...        ...                           ...
# 2301       Urriarra - Namadgi        801  Australian Capital Territory
# 2304         Christmas Island        901             Other Territories
# 2305  Cocos (Keeling) Islands        901             Other Territories
# 2306               Jervis Bay        901             Other Territories
# 2307           Norfolk Island        901             Other Territories
#
#      GCC_CODE16                    GCC_NAME16 STE_CODE16  \
# 0         1RNSW                   Rest of NSW          1
# 1         1RNSW                   Rest of NSW          1
# 2         1RNSW                   Rest of NSW          1
# 3         1RNSW                   Rest of NSW          1
# 4         1RNSW                   Rest of NSW          1
# ...         ...                           ...        ...
# 2301      8ACTE  Australian Capital Territory          8
# 2304      9OTER             Other Territories          9
# 2305      9OTER             Other Territories          9
# 2306      9OTER             Other Territories          9
# 2307      9OTER             Other Territories          9
#
#                         STE_NAME16  AREASQKM16  \
# 0                  New South Wales   3418.3525
# 1                  New South Wales      6.9825
# 2                  New South Wales      4.7634
# 3                  New South Wales     13.0034
# 4                  New South Wales   3054.4099
# ...                            ...         ...
# 2301  Australian Capital Territory   1202.8930
# 2304             Other Territories    136.1356
# 2305             Other Territories     13.7163
# 2306             Other Territories     67.8134
# 2307             Other Territories     38.6509
#
#                                                geometry
# 0     POLYGON ((149.58423 -35.44427, 149.58444 -35.4...
# 1     POLYGON ((149.21898 -35.36739, 149.21799 -35.3...
# 2     POLYGON ((149.21325 -35.34325, 149.21619 -35.3...
# 3     POLYGON ((149.24033 -35.34782, 149.24023 -35.3...
# 4     POLYGON ((149.23580 -35.38738, 149.23771 -35.3...
# ...                                                 ...
# 2301  POLYGON ((148.80406 -35.37620, 148.80416 -35.3...
# 2304  POLYGON ((105.67392 -10.41567, 105.67398 -10.4...
# 2305  MULTIPOLYGON (((96.83047 -12.17636, 96.83045 -...
# 2306  MULTIPOLYGON (((150.69566 -35.18297, 150.69555...
# 2307  MULTIPOLYGON (((167.99472 -29.04534, 167.99432...
#
# [2292 rows x 13 columns]

# %% [markdown]
# # SRID Transformations

# %%
#function borrowed from Week 9 Tutorial to transform Polygon data
def create_wkt_element(geom, srid):
    if geom.geom_type == 'Polygon':
        geom = MultiPolygon([geom])
    return WKTElement(geom.wkt, srid)

# %%
srid = 4326
catchments_og = catchments.copy()
catchments['geom'] = catchments['geometry'].apply(lambda x: create_wkt_element(geom = x, srid = srid))
catchments = catchments.drop(columns = ['geometry', 'PRIORITY'])
#drop school years
school_years =  ['KINDERGART', 'YEAR1', 'YEAR2', 'YEAR3', 'YEAR4', 'YEAR5', 'YEAR6', 'YEAR7', 'YEAR8', 'YEAR9', 'YEAR10', 'YEAR11', 'YEAR12']
catchments = catchments.drop(columns = school_years)
catchments
# Out:
#      USE_ID CATCH_TYPE          USE_DESC  ADD_DATE  \
# 0      2838    PRIMARY        Parklea PS  20181210
# 1      3943    PRIMARY        Gordon WPS  20211219
# 2      2404    PRIMARY     Lindfield EPS  20211219
# 3      4393    PRIMARY   Carlingford WPS  20220223
# 4      4615    PRIMARY    Caddies Ck  PS  20181210
# ...     ...        ...               ...       ...
# 2140   4680    PRIMARY        Googong PS  20220305
# 2141   2540    PRIMARY      Michelago PS  20220305
# 2142   8922  HIGH_COED  Jerrabomberra HS  20220305
# 2143   8919  HIGH_COED     Bungendore HS  20220305
# 2144   8216  HIGH_COED     Queanbeyan HS  20220305
#
#                                                    geom
# 0     MULTIPOLYGON (((150.93563850416004 -33.7161211...
# 1     MULTIPOLYGON (((151.14085043012102 -33.7446267...
# 2     MULTIPOLYGON (((151.1833640465581 -33.74748398...
# 3     MULTIPOLYGON (((151.0451821055135 -33.77303212...
# 4     MULTIPOLYGON (((150.92567327976582 -33.7296030...
# ...                                                 ...
# 2140  MULTIPOLYGON (((149.26653458527704 -35.4983768...
# 2141  MULTIPOLYGON (((149.14237305771536 -35.5687160...
# 2142  MULTIPOLYGON (((149.1980792584528 -35.38147320...
# 2143  MULTIPOLYGON (((149.2408471104619 -34.91439387...
# 2144  MULTIPOLYGON (((149.2567431950555 -35.33185877...
#
# [2145 rows x 5 columns]

# %%
break_ins_og = break_ins.copy()
break_ins['geom'] = break_ins['geometry'].apply(lambda x: create_wkt_element(geom = x, srid = srid))
break_ins = break_ins.drop(columns = 'geometry')
break_ins
# Out:
#       OBJECTID  Contour       Density  ORIG_FID  Shape_Leng  Shape_Area  \
# 0            1      8.0   Low Density         1    0.012138    0.000006
# 1            2      8.0   Low Density         1    0.019106    0.000015
# 2            3      8.0   Low Density         1    0.006068    0.000002
# 3            4      8.0   Low Density         1    0.011006    0.000006
# 4            5      8.0   Low Density         1    0.008073    0.000003
# ...        ...      ...           ...       ...         ...         ...
# 2589      2590     10.0  High Density         3    0.015358    0.000011
# 2590      2591     10.0  High Density         3    0.028327    0.000029
# 2591      2592     10.0  High Density         3    0.006654    0.000002
# 2592      2593     10.0  High Density         3    0.047098    0.000044
# 2593      2594     10.0  High Density         3    0.016336    0.000014
#
#                                                    geom
# 0     MULTIPOLYGON (((149.91078014700008 -37.0663631...
# 1     MULTIPOLYGON (((149.9060088220001 -37.05836717...
# 2     MULTIPOLYGON (((148.94249939000008 -37.0420853...
# 3     MULTIPOLYGON (((149.1958326340001 -36.91833255...
# 4     MULTIPOLYGON (((149.84836006500007 -36.6845891...
# ...                                                 ...
# 2589  MULTIPOLYGON (((153.27961053500007 -28.5538784...
# 2590  MULTIPOLYGON (((150.3593920080001 -28.60530123...
# 2591  MULTIPOLYGON (((153.56824816100004 -28.3830681...
# 2592  MULTIPOLYGON (((153.5391676050001 -28.18857974...
# 2593  MULTIPOLYGON (((153.54242546500006 -28.1699180...
#
# [2594 rows x 7 columns]

# %%
sa_two_og = sa_two.copy()
sa_two['geom'] = sa_two['geometry'].apply(lambda x: create_wkt_element(geom = x, srid = srid))
sa_two = sa_two.drop(columns = 'geometry')
sa_two
# Out:
# bad allocation
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19544/1599238980.py in <module>
#       1 sa_two_og = sa_two.copy()
# ----> 2 sa_two['geom'] = sa_two['geometry'].apply(lambda x: create_wkt_element(geom = x, srid = srid))
#       3 sa_two = sa_two.drop(columns = 'geometry')
#       4 sa_two
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\geopandas\geoseries.py in apply(self, func, convert_dtype, args, **kwargs)
#     622     @doc(pd.Series)
#     623     def apply(self, func, convert_dtype=True, args=(), **kwargs):
# --> 624         result = super().apply(func, convert_dtype=convert_dtype, args=args, **kwargs)
#     625         if isinstance(result, GeoSeries):
#     626             if self.crs is not None:
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_19544/1599238980.py in <lambda>(x)
#       1 sa_two_og = sa_two.copy()
# ----> 2 sa_two['geom'] = sa_two['geometry'].apply(lambda x: create_wkt_element(geom = x, srid = srid))
#       3 sa_two = sa_two.drop(columns = 'geometry')
#       4 sa_two
#
# ~\AppData\Local\Temp/ipykernel_19544/1626537481.py in create_wkt_element(geom, srid)
#       3     if geom.geom_type == 'Polygon':
#       4         geom = MultiPolygon([geom])
# ----> 5     return WKTElement(geom.wkt, srid)
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\shapely\geometry\base.py in wkt(self)
#     369     def wkt(self):
#     370         """WKT representation of the geometry"""
# --> 371         return WKTWriter(lgeos).write(self)
#     372
#     373     @property
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\shapely\geos.py in write(self, geom)
#     426             raise InvalidGeometryError("Null geometry supports no operations")
#     427         result = self._lgeos.GEOSWKTWriter_write(self._writer, geom._geom)
# --> 428         text = string_at(result)
#     429         lgeos.GEOSFree(result)
#     430         return text.decode('ascii')
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\ctypes\__init__.py in string_at(ptr, size)
#     512
#     513     Return the string at addr."""
# --> 514     return _string_at(ptr, size)
#     515
#     516 try:
#
# OSError: exception: access violation reading 0x00000000

# %%
conn.execute("""
DROP TABLE IF EXISTS catchments;
CREATE TABLE catchments (
    "USE_ID" INTEGER,
    "CATCH_TYPE" VARCHAR(20),
    "USE_DESC" VARCHAR(100),
    "ADD_DATE" INTEGER,
    "geom" GEOMETRY(MULTIPOLYGON, 4326)
);""")

conn.execute("""
DROP TABLE IF EXISTS break_ins;
CREATE TABLE break_ins (
    "OBJECTID" INTEGER PRIMARY KEY,
    "Contour" INTEGER,
    "Density" VARCHAR(20),
    "ORIG_FID" INTEGER,
    "Shape_Leng" FLOAT(6),
    "Shape_Area" FLOAT(6),
    "geom" GEOMETRY(MULTIPOLYGON, 4326)
);""")

conn.execute("""
DROP TABLE IF EXISTS sa_two;
CREATE TABLE sa_two (
    "SA2_MAIN16" INTEGER PRIMARY KEY,
    "SA2_5DIG16" INTEGER,
    "SA2_NAME16" VARCHAR(50),
    "SA3_CODE16" INTEGER,
    "SA3_NAME16" VARCHAR(50),
    "SA4_CODE16" INTEGER,
    "SA4_NAME16" VARCHAR(50),
    "GCC_CODE16" VARCHAR(5),
    "GCC_NAME16" VARCHAR(50),
    "STE_CODE16" INTEGER,
    "STE_NAME16" VARCHAR(50),
    "AREASQKM16" FLOAT(4),
    "geom" GEOMETRY(MULTIPOLYGON, 4326)
);""")

# %%
catchments.to_sql("catchments", con = conn, if_exists='append', index = False, dtype = {'geom': Geometry('MULTIPOLYGON', srid)})
query(conn, "SELECT * FROM catchments")
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1787                 if not evt_handled:
# -> 1788                     self.dialect.do_executemany(
#    1789                         cursor, statement, parameters, context
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     950             xtras = self._psycopg2_extras()
# --> 951             context._psycopg2_fetched_rows = xtras.execute_values(
#     952                 cursor,
#
# ~\AppData\Roaming\Python\Python38\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#
# UniqueViolation: duplicate key value violates unique constraint "catchments_pkey"
# DETAIL:  Key ("USE_ID")=(2675) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19544/1420883470.py in <module>
# ----> 1 catchments.to_sql("catchments", con = conn, if_exists='append', index = False, dtype = {'geom': Geometry('MULTIPOLYGON', srid)})
#       2 query(conn, "SELECT * FROM catchments")
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1759         )
#    1760
# -> 1761         sql_engine.insert_records(
#    1762             table=table,
#    1763             con=self.connectable,
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1293             )
#    1294         else:
# -> 1295             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1296
#    1297     def _execute_function(self, func, multiparams, params, execution_options):
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     323     ):
#     324         if _force or self.supports_execution:
# --> 325             return connection._execute_clauseelement(
#     326                 self, multiparams, params, execution_options
#     327             )
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1485             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1486         )
# -> 1487         ret = self._execute_context(
#    1488             dialect,
#    1489             dialect.execution_ctx_cls._init_compiled,
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1849
#    1850         except BaseException as e:
# -> 1851             self._handle_dbapi_exception(
#    1852                 e, statement, parameters, cursor, context
#    1853             )
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2030                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2031             elif should_wrap:
# -> 2032                 util.raise_(
#    2033                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034                 )
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1786                             break
#    1787                 if not evt_handled:
# -> 1788                     self.dialect.do_executemany(
#    1789                         cursor, statement, parameters, context
#    1790                     )
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     949                 kwargs = {}
#     950             xtras = self._psycopg2_extras()
# --> 951             context._psycopg2_fetched_rows = xtras.execute_values(
#     952                 cursor,
#     953                 statement,
#
# ~\AppData\Roaming\Python\Python38\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1268             parts.append(b',')
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#    1272             result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "catchments_pkey"
# DETAIL:  Key ("USE_ID")=(2675) already exists.
#
# [SQL: INSERT INTO catchments ("USE_ID", "CATCH_TYPE", "USE_DESC", "ADD_DATE", geom) VALUES (%(USE_ID)s, %(CATCH_TYPE)s, %(USE_DESC)s, %(ADD_DATE)s, ST_GeomFromEWKT(%(geom)s))]
# [parameters: ({'USE_ID': '2838', 'CATCH_TYPE': 'PRIMARY', 'USE_DESC': 'Parklea PS', 'ADD_DATE': '20181210', 'geom': 'SRID=4326;MULTIPOLYGON (((150.93563850416004 -33.716121104794574, 150.9371498209264 -33.718956658615035, 150.9376428817169 -33.71995410858702, 150.93 ... (4392 characters truncated) ... 664420981 -33.71213995553773, 150.93356449231598 -33.71201897714504, 150.93410987263698 -33.71308411804565, 150.93563850416004 -33.716121104794574)))'}, {'USE_ID': '3943', 'CATCH_TYPE': 'PRIMARY', 'USE_DESC': 'Gordon WPS', 'ADD_DATE': '20211219', 'geom': 'SRID=4326;MULTIPOLYGON (((151.14085043012102 -33.74462679248544, 151.14112516446806 -33.74479444119308, 151.14121050605303 -33.74454690285158, 151.14 ... (4051 characters truncated) ... 17089550122 -33.74693060799583, 151.1377000109003 -33.74656362396007, 151.14025054155465 -33.74435671842808, 151.14085043012102 -33.74462679248544)))'}, {'USE_ID': '2404', 'CATCH_TYPE': 'PRIMARY', 'USE_DESC': 'Lindfield EPS', 'ADD_DATE': '20211219', 'geom': 'SRID=4326;MULTIPOLYGON (((151.1833640465581 -33.74748398847516, 151.18442534768073 -33.74767082275847, 151.18527414584173 -33.74690909172186, 151.185 ... (7115 characters truncated) ... 811493963156 -33.74672945510943, 151.1816787655074 -33.74687310427077, 151.18235578088868 -33.74722538193908, 151.1833640465581 -33.74748398847516)))'}, {'USE_ID': '4393', 'CATCH_TYPE': 'PRIMARY', 'USE_DESC': 'Carlingford WPS', 'ADD_DATE': '20220223', 'geom': 'SRID=4326;MULTIPOLYGON (((151.0451821055135 -33.773032129632355, 151.0452641537892 -33.773379600634605, 151.0473653108162 -33.77327175528031, 151.047 ... (3659 characters truncated) ... 791741387 -33.773339996909606, 151.04467600574674 -33.77309837377432, 151.04477489975463 -33.77309962024885, 151.0451821055135 -33.773032129632355)))'}, {'USE_ID': '4615', 'CATCH_TYPE': 'PRIMARY', 'USE_DESC': 'Caddies Ck  PS', 'ADD_DATE': '20181210', 'geom': 'SRID=4326;MULTIPOLYGON (((150.92567327976582 -33.72960300556872, 150.92601536389685 -33.72975039821291, 150.9261737417179 -33.729535887956686, 150.92 ... (3065 characters truncated) ... 9648882793 -33.72896443265311, 150.9259550156661 -33.729114615142244, 150.92585520667177 -33.72933007558986, 150.92567327976582 -33.72960300556872)))'}, {'USE_ID': '3918', 'CATCH_TYPE': 'PRIMARY', 'USE_DESC': 'Killara PS', 'ADD_DATE': '20211219', 'geom': 'SRID=4326;MULTIPOLYGON (((151.1537883781186 -33.755861740848744, 151.15404333051194 -33.75608975928041, 151.1541049578284 -33.75607608107305, 151.154 ... (2302 characters truncated) ... 85094498418 -33.75576919548745, 151.15208383410604 -33.75434308240826, 151.15251835117058 -33.7542070479885, 151.1537883781186 -33.755861740848744)))'}, {'USE_ID': '3396', 'CATCH_TYPE': 'PRIMARY', 'USE_DESC': 'Waterfall PS', 'ADD_DATE': None, 'geom': 'SRID=4326;MULTIPOLYGON (((150.94786340261896 -34.10594637343694, 150.94785619238056 -34.10587180431659, 150.94787654757127 -34.10578568039837, 150.94 ... (28385 characters truncated) ... 5150886133 -34.106411158608765, 150.9478370652366 -34.106256282176275, 150.9478363798367 -34.10608989332852, 150.94786340261896 -34.10594637343694)))'}, {'USE_ID': '2304', 'CATCH_TYPE': 'PRIMARY', 'USE_DESC': 'Kincumber PS', 'ADD_DATE': '20211115', 'geom': 'SRID=4326;MULTIPOLYGON (((151.39879609368592 -33.44474010261305, 151.40107355468675 -33.445024755216764, 151.40251871047917 -33.44487796021068, 151.4 ... (19686 characters truncated) ... 6250429333 -33.453739034369306, 151.3946301390415 -33.44881529875435, 151.39786803568606 -33.44923732259948, 151.39879609368592 -33.44474010261305)))'}  ... displaying 10 of 2145 total bound parameter sets ...  {'USE_ID': '8919', 'CATCH_TYPE': 'HIGH_COED', 'USE_DESC': 'Bungendore HS', 'ADD_DATE': '20220305', 'geom': 'SRID=4326;MULTIPOLYGON (((149.2408471104619 -34.91439387122756, 149.24366879454504 -34.91475457734963, 149.24383534546084 -34.91462263684491, 149.249 ... (28009 characters truncated) ... 8759573074 -34.912616794194406, 149.22983654010562 -34.91290676111755, 149.2315605200 ...
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
break_ins.to_sql("break_ins", con = conn, if_exists='append', index = False, dtype = {'geom': Geometry('MULTIPOLYGON', srid)})
query(conn, "SELECT * FROM break_ins")
# Out:
#       OBJECTID  Contour       Density  ORIG_FID  Shape_Leng  Shape_Area  \
# 0            1        8   Low Density         1    0.012138    0.000006
# 1            2        8   Low Density         1    0.019106    0.000015
# 2            3        8   Low Density         1    0.006068    0.000002
# 3            4        8   Low Density         1    0.011006    0.000006
# 4            5        8   Low Density         1    0.008073    0.000003
# ...        ...      ...           ...       ...         ...         ...
# 2589      2590       10  High Density         3    0.015358    0.000011
# 2590      2591       10  High Density         3    0.028327    0.000029
# 2591      2592       10  High Density         3    0.006654    0.000002
# 2592      2593       10  High Density         3    0.047098    0.000044
# 2593      2594       10  High Density         3    0.016336    0.000014
#
#                                                    geom
# 0     0106000020E61000000100000001030000000100000015...
# 1     0106000020E6100000010000000103000000010000001D...
# 2     0106000020E61000000100000001030000000100000007...
# 3     0106000020E6100000010000000103000000010000000E...
# 4     0106000020E6100000010000000103000000010000000F...
# ...                                                 ...
# 2589  0106000020E61000000100000001030000000100000016...
# 2590  0106000020E61000000100000001030000000100000028...
# 2591  0106000020E61000000100000001030000000100000009...
# 2592  0106000020E6100000010000000103000000010000004D...
# 2593  0106000020E61000000100000001030000000100000012...
#
# [2594 rows x 7 columns]

# %%
sa_two.to_sql("sa_two", con = conn, if_exists='append', index = False, dtype = {'geom': Geometry('MULTIPOLYGON', srid)})
query(conn, "SELECT * FROM sa_two")
# Out:
#       SA2_MAIN16  SA2_5DIG16               SA2_NAME16  SA3_CODE16  \
# 0      101021007       11007                Braidwood       10102
# 1      101021008       11008                  Karabar       10102
# 2      101031016       11016    Jindabyne - Berridale       10103
# 3      101041017       11017             Batemans Bay       10104
# 4      101041018       11018     Batemans Bay - South       10104
# ...          ...         ...                      ...         ...
# 2287   801111141       81141                  Namadgi       80111
# 2288   901011001       91001         Christmas Island       90101
# 2289   901021002       91002  Cocos (Keeling) Islands       90102
# 2290   901031003       91003               Jervis Bay       90103
# 2291   901041004       91004           Norfolk Island       90104
#
#                    SA3_NAME16  SA4_CODE16                    SA4_NAME16  \
# 0                  Queanbeyan         101                Capital Region
# 1                  Queanbeyan         101                Capital Region
# 2             Snowy Mountains         101                Capital Region
# 3                 South Coast         101                Capital Region
# 4                 South Coast         101                Capital Region
# ...                       ...         ...                           ...
# 2287       Urriarra - Namadgi         801  Australian Capital Territory
# 2288         Christmas Island         901             Other Territories
# 2289  Cocos (Keeling) Islands         901             Other Territories
# 2290               Jervis Bay         901             Other Territories
# 2291           Norfolk Island         901             Other Territories
#
#      GCC_CODE16                    GCC_NAME16  STE_CODE16  \
# 0         1RNSW                   Rest of NSW           1
# 1         1RNSW                   Rest of NSW           1
# 2         1RNSW                   Rest of NSW           1
# 3         1RNSW                   Rest of NSW           1
# 4         1RNSW                   Rest of NSW           1
# ...         ...                           ...         ...
# 2287      8ACTE  Australian Capital Territory           8
# 2288      9OTER             Other Territories           9
# 2289      9OTER             Other Territories           9
# 2290      9OTER             Other Territories           9
# 2291      9OTER             Other Territories           9
#
#                         STE_NAME16  AREASQKM16  \
# 0                  New South Wales   3418.3525
# 1                  New South Wales      6.9825
# 2                  New South Wales   3939.5483
# 3                  New South Wales     63.7074
# 4                  New South Wales     30.5948
# ...                            ...         ...
# 2287  Australian Capital Territory   1202.8930
# 2288             Other Territories    136.1356
# 2289             Other Territories     13.7163
# 2290             Other Territories     67.8134
# 2291             Other Territories     38.6509
#
#                                                    geom
# 0     0106000020E6100000010000000103000000010000005F...
# 1     0106000020E6100000010000000103000000010000002C...
# 2     0106000020E6100000010000000103000000010000005F...
# 3     0106000020E61000000100000001030000000100000036...
# 4     0106000020E6100000070000000103000000010000001C...
# ...                                                 ...
# 2287  0106000020E6100000010000000103000000010000000C...
# 2288  0106000020E61000000100000001030000000100000094...
# 2289  0106000020E6100000380000000103000000010000000E...
# 2290  0106000020E61000000300000001030000000100000017...
# 2291  0106000020E61000001F0000000103000000010000000B...
#
# [2292 rows x 13 columns]

# %% [markdown]
# Since there are two different observations for the number of businesses from the neighbourhoods dataset and the business_stats dataset, we've decided to only use the observation from the business_stats dataset since it's not clear what the neighbourhoods dataset defines as a business. The business_stat data set on the other hand, gives us a clear and detailed count for what types of businesses they have included in their count.

# %%
#sql = """create combined1 AS SELECT N.area_id, N.area_name, N.land_area, N.population, N.number_of_dwellings, N.median_annual_household_income,
#N.avg_monthly_rent, N."0-4", N."5-9",N."10-14", N."15-19", B.number_of_businesses, B.accommodation_and_food_services, B.retail_trade, B.agriculture_forestry_and_fishing, B.health_care_and_social_assistance,
#B.public_administration_and_safety, B.transport_postal_and_warehousing
  #FROM neighbourhoods N
      #LEFT OUTER JOIN business_stats B ON (B.area_id = N.area_id);
      
      #CREATE OR REPLACE VIEW combined2 AS SELECT * FROM combined1 C LEFT OUTER JOIN sa_two S on  (C.area_id = S."SA2_MAIN16");
      
      #SELECT *
#FROM combined2 C join break_ins B   ON ST_Contains(C.geom, B.geom);
      
#"""

#sql2 = """SELECT * from neighbourhoods
#"""
#query(conn,sql)
# Out:
# Error encountered:
# (psycopg2.errors.SyntaxError) syntax error at or near "combined1"
# LINE 1: create combined1 AS SELECT N.area_id, N.area_name, N.land_ar...
#                ^
#
# [SQL: create combined1 AS SELECT N.area_id, N.area_name, N.land_area, N.population, N.number_of_dwellings, N.median_annual_household_income,
# N.avg_monthly_rent, N."0-4", N."5-9",N."10-14", N."15-19", B.number_of_businesses, B.accommodation_and_food_services, B.retail_trade, B.agriculture_forestry_and_fishing, B.health_care_and_social_assistance,
# B.public_administration_and_safety, B.transport_postal_and_warehousing
#   FROM neighbourhoods N
#       LEFT OUTER JOIN business_stats B ON (B.area_id = N.area_id);
#
#       CREATE OR REPLACE VIEW combined2 AS SELECT * FROM combined1 C LEFT OUTER JOIN sa_two S on  (C.area_id = S."SA2_MAIN16");
#
#       SELECT *
# FROM combined2 C join break_ins B   ON ST_Contains(C.geom, B.geom);
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# Empty DataFrame
# Columns: []
# Index: []

# %%
conn.execute("UPDATE neighbourhood SET young_people = (0-4 + 5-9 + 10-14 + 15-19)")
query(conn, "SELECT * FROM neighbourhood")
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19544/2467523148.py in <module>
# ----> 1 conn.execute("UPDATE neighbourhood SET young_people = (0-4 + 5-9 + 10-14 + 15-19)")
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1278             )
#    1279
# -> 1280             return self._exec_driver_sql(
#    1281                 statement,
#    1282                 multiparams,
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1582
#    1583         dialect = self.dialect
# -> 1584         ret = self._execute_context(
#    1585             dialect,
#    1586             dialect.execution_ctx_cls._init_statement,
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704             conn = self._dbapi_connection
#    1705             if conn is None:
# -> 1706                 conn = self._revalidate_connection()
#    1707
#    1708             context = constructor(
#
# c:\Users\georg\AppData\Local\Programs\Python\Python38-32\lib\site-packages\sqlalchemy\engine\base.py in _revalidate_connection(self)
#     574             )
#     575             return self._dbapi_connection
# --> 576         raise exc.ResourceClosedError("This Connection is closed")
#     577
#     578     @property
#
# ResourceClosedError: This Connection is closed

# %%
conn.close()
db.dispose()
